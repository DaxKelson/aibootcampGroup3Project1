# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy.optimize import curve_fit
data = pd.read_csv('/Users/milaadtanha/Downloads/archive/Data/1960/merged_movies_data_1960.csv')
Rating = data['Rating']
budget = data['budget']
plt.figure()
plt.scatter(Rating, budget, label = 'Data', color = 'red')
plt.xlabel('Rating')
plt.ylabel('budget')
plt.title('Budget vs Rating (1960)')
plt.show()

# %%
# %run clean_data.py
# %run main.ipynp
data = pd.read_csv('Users/milaadtanha/Downloads/archive.zip/imdb_all_years.csv')
Rating = data['Rating']
budget = data['budget']
plt.figure()
plt.scatter(Rating, budget, label = 'Data', color = 'red')
plt.xlabel('Rating')
plt.ylabel('budget')
plt.title('Budget vs Rating (1960)')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.12/site-packages/IPython/core/magics/execution.py:716, in ExecutionMagics.run(self, parameter_s, runner, file_finder)
#     715     fpath = arg_lst[0]
# --> 716     filename = file_finder(fpath)
#     717 except IndexError as e:
#
# File /opt/anaconda3/lib/python3.12/site-packages/IPython/utils/path.py:91, in get_py_filename(name)
#      90         return py_name
# ---> 91 raise IOError("File `%r` not found." % name)
#
# OSError: File `'clean_data.py'` not found.
#
# The above exception was the direct cause of the following exception:
#
# Exception                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 get_ipython().run_line_magic('run', 'clean_data.py')
#       2 get_ipython().run_line_magic('run', 'main.ipynp')
# ...
